# %% [markdown]
# ###  Pandas
# - Used for data manipulation and processing
#     - 2 Data structures in python pandas
#         - Series -> sequence of data objects like int,float,string, data types etc..
#                 It's like 1D array of elements
#                 Syntax: pd.Series(data,index,dtype)
#         - Data Frames

# %%
import pandas as pd
a=pd.Series([5,6,3])
a
# Out:
# 0    5
# 1    6
# 2    3
# dtype: int64

# %%
ch=pd.Series(['r','u','t','h','u'])
ch
# Out:
# 0    r
# 1    u
# 2    t
# 3    h
# 4    u
# dtype: object

# %%
fl=pd.Series((12.4,45.7,87.34))
fl
# Out:
# 0    12.40
# 1    45.70
# 2    87.34
# dtype: float64

# %%
# Assigning values to the index variable

ar=pd.Series(['r','u','t','h','u'],index=(4,5,8,2,9))
ar
# Out:
# 4    r
# 5    u
# 8    t
# 2    h
# 9    u
# dtype: object

# %%
dt=pd.Series((23,24,25),index=pd.date_range('22-10-2019','24-10-2019'))
dt
# Out:
# 2019-10-22    23
# 2019-10-23    24
# 2019-10-24    25
# Freq: D, dtype: int64

# %% [markdown]
# ####  Data Frames
# - 2Dimensional array type of structure used for data analysis
# - Can be created using lists,dictionaries,JSON objects,.txt .csv files etc.

# %%
import pandas as pd
data=[['a',12],['b',74],['c',39]]
df=pd.DataFrame(data,columns=['name','age'])
df
# Out:
#   name  age
# 0    a   12
# 1    b   74
# 2    c   39

# %%
internal1={'stu1':21,'stu2':20,'stu3':22}
data1=pd.Series(internal1)
internal2={'stu1':23,'stu2':22,'stu3':24}
data2=pd.Series(internal2)
print(data1)
print(data2)
# Out:
# stu1    21
# stu2    20
# stu3    22
# dtype: int64
# stu1    23
# stu2    22
# stu3    24
# dtype: int64

# %%
final={'internal1':data1,'internal2':data2}
final_data=pd.DataFrame(final)
final_data
# Out:
#       internal1  internal2
# stu1         21         23
# stu2         20         22
# stu3         22         24

# %%
#Program to create a dictionary of name, age and occupation. Frames of create dictionary.
dic={'name':['Vijay','Vinay','Ravi'],'age':[23,27,26],'Occupation':['Farmer','Engineer','MBA']}
data=pd.DataFrame(dic,index=['Person1','Person2','Person3'])
data
# Out:
#           name  age Occupation
# Person1  Vijay   23     Farmer
# Person2  Vinay   27   Engineer
# Person3   Ravi   26        MBA

# %%
#Program to Import CSV data files as a pandas data frames
#data='olympics.csv'
#df=pd.read_csv(data)
df=pd.read_csv('olympics.csv')
df
# Out:
#                                                 0         1     2     3     4  \
# 0                                             NaN  № Summer  01 !  02 !  03 !
# 1                               Afghanistan (AFG)        13     0     0     2
# 2                                   Algeria (ALG)        12     5     2     8
# 3                                 Argentina (ARG)        23    18    24    28
# 4                                   Armenia (ARM)         5     1     2     9
# 5                         Australasia (ANZ) [ANZ]         2     3     4     5
# 6                       Australia (AUS) [AUS] [Z]        25   139   152   177
# 7                                   Austria (AUT)        26    18    33    35
# 8                                Azerbaijan (AZE)         5     6     5    15
# 9                                   Bahamas (BAH)        15     5     2     5
# 10                                  Bahrain (BRN)         8     0     0     1
# ...

# %%
#Program to retrive the states with total no.of games
for column in df.values:
    print(column[0],':',column[4])
# Out:
# nan : 03 !
# Afghanistan (AFG) : 2
# Algeria (ALG) : 8
# Argentina (ARG) : 28
# Armenia (ARM) : 9
# Australasia (ANZ) [ANZ] : 5
# Australia (AUS) [AUS] [Z] : 177
# Austria (AUT) : 35
# Azerbaijan (AZE) : 15
# Bahamas (BAH) : 5
# Bahrain (BRN) : 1
# Barbados (BAR) [BAR] : 1
# Belarus (BLR) : 39
# Belgium (BEL) : 53
# Bermuda (BER) : 1
# Bohemia (BOH) [BOH] [Z] : 3
# Botswana (BOT) : 0
# Brazil (BRA) : 55
# British West Indies (BWI) [BWI] : 2
# Bulgaria (BUL) [H] : 78
# Burundi (BDI) : 0
# Cameroon (CMR) : 1
# Canada (CAN) : 121
# Chile (CHI) [I] : 4
# China (CHN) [CHN] : 126
# Colombia (COL) : 11
# Costa Rica (CRC) : 2
# Ivory Coast (CIV) [CIV] : 0
# Croatia (CRO) : 10
# Cuba (CUB) [Z] : 70
# Cyprus (CYP) : 0
# Czech Republic (CZE) [CZE] : 15
# Czechoslovakia (TCH) [TCH] : 45
# Denmark (DEN) [Z] : 68
# Djibouti (DJI) [B] : 1
# Dominican Republic (DOM) : 1
# Ecuador (ECU) : 0
# Egypt (EGY) [EGY] [Z] : 10
# Eritrea (ERI) : 1
# Estonia (EST) : 15
# Ethiopia (ETH) : 17
# ...

# %%
census=pd.read_csv('census.csv')
census
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
for value in census.values:
    print(value[5],":",value[6],":",value[7])
# Out:
# Alabama : Alabama : 4779736
# Alabama : Autauga County : 54571
# Alabama : Baldwin County : 182265
# Alabama : Barbour County : 27457
# Alabama : Bibb County : 22915
# Alabama : Blount County : 57322
# Alabama : Bullock County : 10914
# Alabama : Butler County : 20947
# Alabama : Calhoun County : 118572
# Alabama : Chambers County : 34215
# Alabama : Cherokee County : 25989
# Alabama : Chilton County : 43643
# Alabama : Choctaw County : 13859
# Alabama : Clarke County : 25833
# Alabama : Clay County : 13932
# Alabama : Cleburne County : 14972
# Alabama : Coffee County : 49948
# Alabama : Colbert County : 54428
# Alabama : Conecuh County : 13228
# Alabama : Coosa County : 11539
# Alabama : Covington County : 37765
# Alabama : Crenshaw County : 13906
# Alabama : Cullman County : 80406
# Alabama : Dale County : 50251
# Alabama : Dallas County : 43820
# Alabama : DeKalb County : 71109
# Alabama : Elmore County : 79303
# Alabama : Escambia County : 38319
# ...

# %%
# Average population of Country Alabama

# %% [markdown]
# ####  matplot lib
# - Used for ploting of 2D data

# %%
import matplotlib.pyplot as plt
plt.title('Linear Graph')
plt.plot([1,2,3,4],[5,6,7,8])
plt.show()

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_autogen_docstring',
#  '_backend_mod',
#  '_get_running_interactive_framework',
#  '_interactive_bk',
#  '_log',
# ...

# %%
#Plot a graph between Distance and Time
time=list(range(2,11,2))
distance=list(range(1,6))
plt.title('Distance vs Time')
plt.xlabel('Time')
plt.ylabel('Distance')
plt.plot(time,distance,'yo')
plt.grid()
plt.show()

# %%
#Non-linear graph for the equation v=a*t
# velocity=avg*time
    # v=a*t
import matplotlib.pyplot as plt

t=list(range(1,11))
a=list(range(1,len(t)+1))
v=[a[time]*time for time in range(1,len(t))]
plt.plot(t,v)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-ccacc306b63a> in <module>
#       7 a=list(range(1,len(t)+1))
#       8 v=[a[time]*time for time in range(1,len(t))]
# ----> 9 plt.plot(t,v)
#      10 plt.grid()
#      11 plt.show()
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %% [markdown]
# # Assignment 2 - Pandas Introduction
# All questions are weighted the same in this assignment.
# ## Part 1
# The following code loads the olympics dataset (olympics.csv), which was derrived from the Wikipedia entry on [All Time Olympic Games Medals](https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table), and does some basic data cleaning.
#
# The columns are organized as # of Summer games, Summer medals, # of Winter games, Winter medals, total # number of games, total # of medals. Use this dataset to answer the questions below.

# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df.drop('Totals',axis=0,inplace=True)
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
df
# Out:
#                                   # Summer  Gold  Silver  Bronze  Total  \
# Afghanistan                             13     0       0       2      2
# Algeria                                 12     5       2       8     15
# Argentina                               23    18      24      28     70
# Armenia                                  5     1       2       9     12
# Australasia                              2     3       4       5     12
# Australia                               25   139     152     177    468
# Austria                                 26    18      33      35     86
# Azerbaijan                               5     6       5      15     26
# Bahamas                                 15     5       2       5     12
# Bahrain                                  8     0       0       1      1
# Barbados                                11     0       0       1      1
# Belarus                                  5    12      24      39     75
# ...

# %%
def ans_zero():
    return pd.Series(df.values[0])

ans_zero()
# Out:
# 0      13
# 1       0
# 2       0
# 3       2
# 4       2
# 5       0
# 6       0
# 7       0
# 8       0
# 9       0
# 10     13
# 11      0
# 12      0
# 13      2
# 14      2
# 15    AFG
# dtype: object

# %%
gold_medal_cnt=max(list(df['Gold']))
#gold_medal_cnt
df['Gold'].idxmax()
# Out:
# 'United States'

# %%
def max_gold():
    return df[df['Gold']==df['Gold'].max()].index[0]

max_gold()
# Out:
# 'United States'

# %%
m=df['Gold'].max()
count=0
for country in df.values:
    count+=1
    if country[1]==m:
        print(df.index[count-1])
        
m
# Out:
# United States
# 976

# %%
def ans_two():
    diff=0
    country=df.index[0]
    for item in range(1,len(df.values)):
        new_diff=df.values[item][1]-df.values[item][6]
        if new_diff>diff:
            diff=new_diff
            country=df.index[item]
    return country

ans_two()
# Out:
# 'United States'

# %% [markdown]
# ### Question 4
# Write a function that creates a Series called "Points" which is a weighted value where each gold medal (`Gold.2`) counts for 3 points, silver medals (`Silver.2`) for 2 points, and bronze medals (`Bronze.2`) for 1 point. The function should return only the column (a Series object) which you created, with the country names as indices.
#
# *This function should return a Series named `Points` of length 146*

# %%
def ans_four():
    li=[]
    for row in df.values:
        li.append(row[11]*3+row[12]*2+row[13])
    li
    return pd.Series(li,index=df.index)
ans_four()
# Out:
# Afghanistan                            2
# Algeria                               27
# Argentina                            130
# Armenia                               16
# Australasia                           22
# Australia                            923
# Austria                              569
# Azerbaijan                            43
# Bahamas                               24
# Bahrain                                1
# Barbados                               1
# Belarus                              154
# Belgium                              276
# Bermuda                                1
# Bohemia                                5
# Botswana                               2
# Brazil                               184
# British West Indies                    2
# Bulgaria                             411
# Burundi                                3
# Cameroon                              12
# Canada                               846
# Chile                                 24
# ...

# %% [markdown]
# ## Part 2
# For the next set of questions, we will be using census data from the [United States Census Bureau](http://www.census.gov). Counties are political and geographic subdivisions of states in the United States. This dataset contains population data for counties and states in the US from 2010 to 2015. [See this document](https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2010-2015/co-est2015-alldata.pdf) for a description of the variable names.
#
# The census dataset (census.csv) should be loaded as census_df. Answer questions using this as appropriate.
#
# ### Question 5
# Which state has the most counties in it? (hint: consider the sumlevel key carefully! You'll need this for future questions too...)
#
# *This function should return a single string value.*

# %%
import pandas as pd
census_df = pd.read_csv('census.csv')
census_df

# %%
census_df.head()

# %%
census_df.tail()

# %%
def answer_five():
    dic={}
    for col in census_df.values:
        if col[0]==50:
            dic[col[5]]+=1
        else:
            dic[col[5]]=0
    m=max(dic.values())
    for item in dic.items():
        if item[1]==m:
            state=item[0]
    
    return state
answer_five()
